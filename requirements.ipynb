# %%
# !pip install helpers
# Out:
# Collecting helpers
#   Downloading helpers-0.2.0-py3-none-any.whl.metadata (708 bytes)
# Downloading helpers-0.2.0-py3-none-any.whl (2.3 kB)
# Installing collected packages: helpers
# Successfully installed helpers-0.2.0

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp312-cp312-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 56.1 MB/s eta 0:00:00a 0:00:01
# Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 35.9 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 20.2 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.26.4 pandas-2.2.2 pytz-2024.1 tzdata-2024.1

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (1.26.4)

# %%
pip install 'langkit[all]'
# Out:
# Requirement already satisfied: langkit[all] in ./.venv/lib/python3.12/site-packages (0.0.31)
# Requirement already satisfied: datasets<3.0.0,>=2.12.0 in ./.venv/lib/python3.12/site-packages (from langkit[all]) (2.19.0)
# Collecting detoxify<0.6.0,>=0.5.2 (from langkit[all])
#   Downloading detoxify-0.5.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: evaluate<0.5.0,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from langkit[all]) (0.4.1)
# Collecting h5py<4.0.0,>=3.10.0 (from langkit[all])
#   Downloading h5py-3.11.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Collecting ipywidgets<9.0.0,>=8.1.1 (from langkit[all])
#   Downloading ipywidgets-8.1.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting nltk<4.0.0,>=3.8.1 (from langkit[all])
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (from langkit[all]) (1.26.4)
# Requirement already satisfied: openai<2.0.0,>=0.27.6 in ./.venv/lib/python3.12/site-packages (from langkit[all]) (1.23.2)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (from langkit[all]) (2.2.2)
# Collecting presidio-analyzer<3.0.0,>=2.2.351 (from langkit[all])
#   Downloading presidio_analyzer-2.2.354-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sentence-transformers<3.0.0,>=2.2.2 in ./.venv/lib/python3.12/site-packages (from langkit[all]) (2.7.0)
# Requirement already satisfied: textstat<0.8.0,>=0.7.3 in ./.venv/lib/python3.12/site-packages (from langkit[all]) (0.7.3)
# Requirement already satisfied: torch in ./.venv/lib/python3.12/site-packages (from langkit[all]) (2.2.2)
# Collecting vadersentiment<4.0.0,>=3.3.2 (from langkit[all])
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Requirement already satisfied: whylogs<2.0.0,>=1.3.19 in ./.venv/lib/python3.12/site-packages (from langkit[all]) (1.3.30)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (3.13.4)
# Requirement already satisfied: pyarrow>=12.0.0 in ./.venv/lib/python3.12/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (16.0.0)
# Requirement already satisfied: pyarrow-hotfix in ./.venv/lib/python3.12/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in ./.venv/lib/python3.12/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (0.3.8)
# Requirement already satisfied: requests>=2.19.0 in ./.venv/lib/python3.12/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in ./.venv/lib/python3.12/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (4.66.2)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.12/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (3.4.1)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.12/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (0.70.16)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in ./.venv/lib/python3.12/site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets<3.0.0,>=2.12.0->langkit[all]) (2024.3.1)
# Requirement already satisfied: aiohttp in ./.venv/lib/python3.12/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in ./.venv/lib/python3.12/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (0.22.2)
# Requirement already satisfied: packaging in ./.venv/lib/python3.12/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.12/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (6.0.1)
# Requirement already satisfied: transformers in ./.venv/lib/python3.12/site-packages (from detoxify<0.6.0,>=0.5.2->langkit[all]) (4.40.0)
# Collecting sentencepiece>=0.1.94 (from detoxify<0.6.0,>=0.5.2->langkit[all])
#   Downloading sentencepiece-0.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Requirement already satisfied: responses<0.19 in ./.venv/lib/python3.12/site-packages (from evaluate<0.5.0,>=0.4.0->langkit[all]) (0.18.0)
# Requirement already satisfied: comm>=0.1.3 in ./.venv/lib/python3.12/site-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in ./.venv/lib/python3.12/site-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (8.12.3)
# Requirement already satisfied: traitlets>=4.3.1 in ./.venv/lib/python3.12/site-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (5.14.3)
# Collecting widgetsnbextension~=4.0.10 (from ipywidgets<9.0.0,>=8.1.1->langkit[all])
#   Downloading widgetsnbextension-4.0.10-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.10 (from ipywidgets<9.0.0,>=8.1.1->langkit[all])
#   Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl.metadata (4.1 kB)
# Collecting click (from nltk<4.0.0,>=3.8.1->langkit[all])
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: joblib in ./.venv/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->langkit[all]) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->langkit[all]) (2024.4.16)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.12/site-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.12/site-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.12/site-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./.venv/lib/python3.12/site-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (2.7.1)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.12/site-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in ./.venv/lib/python3.12/site-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (4.11.0)
# Collecting spacy<4.0.0,>=3.4.4 (from presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading spacy-3.7.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (27 kB)
# Collecting tldextract (from presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading tldextract-5.1.2-py3-none-any.whl.metadata (11 kB)
# Collecting phonenumbers<9.0.0,>=8.12 (from presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading phonenumbers-8.13.35-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.12/site-packages (from sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (1.4.2)
# Requirement already satisfied: scipy in ./.venv/lib/python3.12/site-packages (from sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (1.13.0)
# Requirement already satisfied: Pillow in ./.venv/lib/python3.12/site-packages (from sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (10.3.0)
# Requirement already satisfied: pyphen in ./.venv/lib/python3.12/site-packages (from textstat<0.8.0,>=0.7.3->langkit[all]) (0.15.0)
# Requirement already satisfied: sympy in ./.venv/lib/python3.12/site-packages (from torch->langkit[all]) (1.12)
# Requirement already satisfied: networkx in ./.venv/lib/python3.12/site-packages (from torch->langkit[all]) (3.3)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from torch->langkit[all]) (3.1.3)
# Requirement already satisfied: platformdirs<4.0.0,>=3.5.0 in ./.venv/lib/python3.12/site-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (3.11.0)
# Requirement already satisfied: protobuf>=3.19.4 in ./.venv/lib/python3.12/site-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (5.26.1)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.30.0.0 in ./.venv/lib/python3.12/site-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (2.31.0.20240406)
# Requirement already satisfied: whylabs-client<0.7.0,>=0.6.0 in ./.venv/lib/python3.12/site-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (0.6.2)
# Requirement already satisfied: whylogs-sketching>=3.4.1.dev3 in ./.venv/lib/python3.12/site-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (3.4.1.dev3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas->langkit[all]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas->langkit[all]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas->langkit[all]) (2024.1)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=0.27.6->langkit[all]) (3.7)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.12/site-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.12/site-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (1.9.4)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=0.27.6->langkit[all]) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=0.27.6->langkit[all]) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=0.27.6->langkit[all]) (0.14.0)
# Requirement already satisfied: backcall in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.2.0)
# Requirement already satisfied: decorator in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.19.1)
# Requirement already satisfied: matplotlib-inline in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.1.7)
# Requirement already satisfied: pickleshare in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (2.17.2)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (4.9.0)
# Requirement already satisfied: appnope in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.1.4)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai<2.0.0,>=0.27.6->langkit[all]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai<2.0.0,>=0.27.6->langkit[all]) (2.18.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->langkit[all]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.19.0->datasets<3.0.0,>=2.12.0->langkit[all]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.19.0->datasets<3.0.0,>=2.12.0->langkit[all]) (2.2.1)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading murmurhash-1.0.10-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading cymem-2.0.8-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading preshed-3.0.9-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading thinc-8.2.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading wasabi-1.1.2-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading srsly-2.4.8-cp312-cp312-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading weasel-0.3.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting typer<0.10.0,>=0.3.0 (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Using cached typer-0.9.4-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<7.0.0,>=5.2.1 (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting setuptools (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Using cached setuptools-69.5.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading langcodes-3.3.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in ./.venv/lib/python3.12/site-packages (from transformers->detoxify<0.6.0,>=0.5.2->langkit[all]) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in ./.venv/lib/python3.12/site-packages (from transformers->detoxify<0.6.0,>=0.5.2->langkit[all]) (0.4.3)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2->torch->langkit[all]) (2.1.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn->sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (3.4.0)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.12/site-packages (from sympy->torch->langkit[all]) (1.3.0)
# Collecting requests-file>=1.4 (from tldextract->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading requests_file-2.0.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.7.0)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.12/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.2.13)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading blis-0.7.11-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading confection-0.1.4-py3-none-any.whl.metadata (19 kB)
# Collecting cloudpathlib<0.17.0,>=0.7.0 (from weasel<0.4.0,>=0.1.0->spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all])
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (2.4.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.2.2)
# Downloading detoxify-0.5.2-py3-none-any.whl (12 kB)
# Downloading h5py-3.11.0-cp312-cp312-macosx_11_0_arm64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 29.1 MB/s eta 0:00:00a 0:00:01
# Downloading ipywidgets-8.1.2-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 18.9 MB/s eta 0:00:00
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 64.8 MB/s eta 0:00:00
# Downloading presidio_analyzer-2.2.354-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 kB 11.5 MB/s eta 0:00:00
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 17.2 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl (215 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 kB 23.1 MB/s eta 0:00:00
# Downloading phonenumbers-8.13.35-py2.py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 65.9 MB/s eta 0:00:0000:01
# Downloading sentencepiece-0.2.0-cp312-cp312-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 50.5 MB/s eta 0:00:00
# Downloading spacy-3.7.4-cp312-cp312-macosx_11_0_arm64.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 61.4 MB/s eta 0:00:00a 0:00:01
# Downloading widgetsnbextension-4.0.10-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 69.5 MB/s eta 0:00:00
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading tldextract-5.1.2-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.6/97.6 kB 9.7 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.8-cp312-cp312-macosx_11_0_arm64.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 5.6 MB/s eta 0:00:00
# Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 23.0 MB/s eta 0:00:00
# Downloading murmurhash-1.0.10-cp312-cp312-macosx_11_0_arm64.whl (26 kB)
# Downloading preshed-3.0.9-cp312-cp312-macosx_11_0_arm64.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.6/128.6 kB 14.7 MB/s eta 0:00:00
# Downloading requests_file-2.0.0-py2.py3-none-any.whl (4.2 kB)
# Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 6.9 MB/s eta 0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp312-cp312-macosx_11_0_arm64.whl (486 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.4/486.4 kB 42.4 MB/s eta 0:00:00
# Downloading thinc-8.2.3-cp312-cp312-macosx_11_0_arm64.whl (760 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.5/760.5 kB 45.4 MB/s eta 0:00:00
# Using cached typer-0.9.4-py3-none-any.whl (45 kB)
# Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Downloading weasel-0.3.4-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 5.4 MB/s eta 0:00:00
# Using cached setuptools-69.5.1-py3-none-any.whl (894 kB)
# Downloading blis-0.7.11-cp312-cp312-macosx_11_0_arm64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 38.0 MB/s eta 0:00:00
# Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 4.4 MB/s eta 0:00:00
# Downloading confection-0.1.4-py3-none-any.whl (35 kB)
# Installing collected packages: sentencepiece, phonenumbers, cymem, widgetsnbextension, wasabi, spacy-loggers, spacy-legacy, smart-open, setuptools, murmurhash, langcodes, jupyterlab-widgets, h5py, cloudpathlib, click, catalogue, blis, vadersentiment, typer, srsly, requests-file, preshed, nltk, tldextract, confection, weasel, thinc, ipywidgets, spacy, detoxify, presidio-analyzer
# Successfully installed blis-0.7.11 catalogue-2.0.10 click-8.1.7 cloudpathlib-0.16.0 confection-0.1.4 cymem-2.0.8 detoxify-0.5.2 h5py-3.11.0 ipywidgets-8.1.2 jupyterlab-widgets-3.0.10 langcodes-3.3.0 murmurhash-1.0.10 nltk-3.8.1 phonenumbers-8.13.35 preshed-3.0.9 presidio-analyzer-2.2.354 requests-file-2.0.0 sentencepiece-0.2.0 setuptools-69.5.1 smart-open-6.4.0 spacy-3.7.4 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.3 tldextract-5.1.2 typer-0.9.4 vadersentiment-3.3.2 wasabi-1.1.2 weasel-0.3.4 widgetsnbextension-4.0.10
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in ./.venv/lib/python3.12/site-packages (3.8.1)
# Requirement already satisfied: click in ./.venv/lib/python3.12/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in ./.venv/lib/python3.12/site-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.12/site-packages (from nltk) (2024.4.16)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.12/site-packages (from nltk) (4.66.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install whylogs
# Out:
# Requirement already satisfied: whylogs in ./.venv/lib/python3.12/site-packages (1.3.30)
# Requirement already satisfied: platformdirs<4.0.0,>=3.5.0 in ./.venv/lib/python3.12/site-packages (from whylogs) (3.11.0)
# Requirement already satisfied: protobuf>=3.19.4 in ./.venv/lib/python3.12/site-packages (from whylogs) (5.26.1)
# Requirement already satisfied: requests<3.0,>=2.27 in ./.venv/lib/python3.12/site-packages (from whylogs) (2.31.0)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.30.0.0 in ./.venv/lib/python3.12/site-packages (from whylogs) (2.31.0.20240406)
# Requirement already satisfied: typing-extensions>=3.10 in ./.venv/lib/python3.12/site-packages (from whylogs) (4.11.0)
# Requirement already satisfied: whylabs-client<0.7.0,>=0.6.0 in ./.venv/lib/python3.12/site-packages (from whylogs) (0.6.2)
# Requirement already satisfied: whylogs-sketching>=3.4.1.dev3 in ./.venv/lib/python3.12/site-packages (from whylogs) (3.4.1.dev3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests<3.0,>=2.27->whylogs) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests<3.0,>=2.27->whylogs) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests<3.0,>=2.27->whylogs) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests<3.0,>=2.27->whylogs) (2024.2.2)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.12/site-packages (from whylabs-client<0.7.0,>=0.6.0->whylogs) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil->whylabs-client<0.7.0,>=0.6.0->whylogs) (1.16.0)

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting datasets>=2.0.0 (from evaluate)
#   Downloading datasets-2.19.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.12/site-packages (from evaluate) (1.26.4)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in ./.venv/lib/python3.12/site-packages (from evaluate) (2.31.0)
# Collecting tqdm>=4.62.1 (from evaluate)
#   Using cached tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
# Collecting xxhash (from evaluate)
#   Downloading xxhash-3.4.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec>=2021.05.0 (from fsspec[http]>=2021.05.0->evaluate)
#   Downloading fsspec-2024.3.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting huggingface-hub>=0.7.0 (from evaluate)
#   Downloading huggingface_hub-0.22.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging in ./.venv/lib/python3.12/site-packages (from evaluate) (24.0)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl.metadata (29 kB)
# Collecting filelock (from datasets>=2.0.0->evaluate)
#   Downloading filelock-3.13.4-py3-none-any.whl.metadata (2.8 kB)
# Collecting pyarrow>=12.0.0 (from datasets>=2.0.0->evaluate)
#   Downloading pyarrow-16.0.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting pyarrow-hotfix (from datasets>=2.0.0->evaluate)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting aiohttp (from datasets>=2.0.0->evaluate)
#   Using cached aiohttp-3.9.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Collecting pyyaml>=5.1 (from datasets>=2.0.0->evaluate)
#   Using cached PyYAML-6.0.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv/lib/python3.12/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas->evaluate) (2024.1)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets>=2.0.0->evaluate)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp->datasets>=2.0.0->evaluate)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets>=2.0.0->evaluate)
#   Using cached frozenlist-1.4.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets>=2.0.0->evaluate)
#   Using cached multidict-6.0.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets>=2.0.0->evaluate)
#   Using cached yarl-1.9.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.5 MB/s eta 0:00:00
# Downloading datasets-2.19.0-py3-none-any.whl (542 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 11.6 MB/s eta 0:00:00a 0:00:01
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.0 MB/s eta 0:00:00
# Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 23.1 MB/s eta 0:00:00
# Downloading huggingface_hub-0.22.2-py3-none-any.whl (388 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 30.1 MB/s eta 0:00:00
# Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Using cached tqdm-4.66.2-py3-none-any.whl (78 kB)
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 15.1 MB/s eta 0:00:00
# Downloading xxhash-3.4.1-cp312-cp312-macosx_11_0_arm64.whl (30 kB)
# Using cached aiohttp-3.9.5-cp312-cp312-macosx_11_0_arm64.whl (392 kB)
# Downloading pyarrow-16.0.0-cp312-cp312-macosx_11_0_arm64.whl (26.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.0/26.0 MB 54.5 MB/s eta 0:00:0000:0100:01
# Using cached PyYAML-6.0.1-cp312-cp312-macosx_11_0_arm64.whl (165 kB)
# Downloading filelock-3.13.4-py3-none-any.whl (11 kB)
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached frozenlist-1.4.1-cp312-cp312-macosx_11_0_arm64.whl (51 kB)
# Using cached multidict-6.0.5-cp312-cp312-macosx_11_0_arm64.whl (29 kB)
# Using cached yarl-1.9.4-cp312-cp312-macosx_11_0_arm64.whl (79 kB)
# Installing collected packages: xxhash, tqdm, pyyaml, pyarrow-hotfix, pyarrow, multidict, fsspec, frozenlist, filelock, dill, attrs, yarl, responses, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets, evaluate
# Successfully installed aiohttp-3.9.5 aiosignal-1.3.1 attrs-23.2.0 datasets-2.19.0 dill-0.3.8 evaluate-0.4.1 filelock-3.13.4 frozenlist-1.4.1 fsspec-2024.3.1 huggingface-hub-0.22.2 multidict-6.0.5 multiprocess-0.70.16 pyarrow-16.0.0 pyarrow-hotfix-0.6 pyyaml-6.0.1 responses-0.18.0 tqdm-4.66.2 xxhash-3.4.1 yarl-1.9.4

# %%
# !pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl.metadata (11 kB)
# Collecting transformers<5.0.0,>=4.34.0 (from sentence_transformers)
#   Downloading transformers-4.40.0-py3-none-any.whl.metadata (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 3.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: tqdm in ./.venv/lib/python3.12/site-packages (from sentence_transformers) (4.66.2)
# Collecting torch>=1.11.0 (from sentence_transformers)
#   Downloading torch-2.2.2-cp312-none-macosx_11_0_arm64.whl.metadata (25 kB)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (from sentence_transformers) (1.26.4)
# Collecting scikit-learn (from sentence_transformers)
#   Downloading scikit_learn-1.4.2-cp312-cp312-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting scipy (from sentence_transformers)
#   Downloading scipy-1.13.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.15.1 in ./.venv/lib/python3.12/site-packages (from sentence_transformers) (0.22.2)
# Collecting Pillow (from sentence_transformers)
#   Downloading pillow-10.3.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.13.4)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in ./.venv/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.1)
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.11.0)
# Collecting sympy (from torch>=1.11.0->sentence_transformers)
#   Downloading sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.11.0->sentence_transformers)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting jinja2 (from torch>=1.11.0->sentence_transformers)
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.34.0->sentence_transformers)
#   Using cached regex-2024.4.16-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting tokenizers<0.20,>=0.19 (from transformers<5.0.0,>=4.34.0->sentence_transformers)
#   Downloading tokenizers-0.19.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers<5.0.0,>=4.34.0->sentence_transformers)
#   Downloading safetensors-0.4.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence_transformers)
#   Downloading joblib-1.4.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->sentence_transformers)
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl.metadata (13 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.11.0->sentence_transformers)
#   Downloading MarkupSafe-2.1.5-cp312-cp312-macosx_10_9_universal2.whl.metadata (3.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2024.2.2)
# Collecting mpmath>=0.19 (from sympy->torch>=1.11.0->sentence_transformers)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 12.1 MB/s eta 0:00:00
# Downloading torch-2.2.2-cp312-none-macosx_11_0_arm64.whl (59.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 MB 54.0 MB/s eta 0:00:0000:0100:01
# Downloading transformers-4.40.0-py3-none-any.whl (9.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 65.3 MB/s eta 0:00:00a 0:00:01
# Downloading pillow-10.3.0-cp312-cp312-macosx_11_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 67.7 MB/s eta 0:00:00a 0:00:01
# Downloading scikit_learn-1.4.2-cp312-cp312-macosx_12_0_arm64.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 62.9 MB/s eta 0:00:0000:010:01
# Downloading scipy-1.13.0-cp312-cp312-macosx_12_0_arm64.whl (30.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.4/30.4 MB 54.8 MB/s eta 0:00:0000:0100:01
# Downloading joblib-1.4.0-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.2/301.2 kB 36.7 MB/s eta 0:00:00
# Using cached regex-2024.4.16-cp312-cp312-macosx_11_0_arm64.whl (292 kB)
# Downloading safetensors-0.4.3-cp312-cp312-macosx_11_0_arm64.whl (411 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.1/411.1 kB 38.7 MB/s eta 0:00:00
# Downloading threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Downloading tokenizers-0.19.1-cp312-cp312-macosx_11_0_arm64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 49.2 MB/s eta 0:00:00a 0:00:01
# Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 18.0 MB/s eta 0:00:00
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 40.1 MB/s eta 0:00:0000:01
# Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 65.9 MB/s eta 0:00:00a 0:00:01
# Downloading MarkupSafe-2.1.5-cp312-cp312-macosx_10_9_universal2.whl (18 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 57.6 MB/s eta 0:00:00
# Installing collected packages: mpmath, threadpoolctl, sympy, scipy, safetensors, regex, Pillow, networkx, MarkupSafe, joblib, scikit-learn, jinja2, torch, tokenizers, transformers, sentence_transformers
# Successfully installed MarkupSafe-2.1.5 Pillow-10.3.0 jinja2-3.1.3 joblib-1.4.0 mpmath-1.3.0 networkx-3.3 regex-2024.4.16 safetensors-0.4.3 scikit-learn-1.4.2 scipy-1.13.0 sentence_transformers-2.7.0 sympy-1.12 threadpoolctl-3.4.0 tokenizers-0.19.1 torch-2.2.2 transformers-4.40.0

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in ./.venv/lib/python3.12/site-packages (4.40.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from transformers) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in ./.venv/lib/python3.12/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.12/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.12/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in ./.venv/lib/python3.12/site-packages (from transformers) (2024.4.16)
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in ./.venv/lib/python3.12/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in ./.venv/lib/python3.12/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in ./.venv/lib/python3.12/site-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests->transformers) (2024.2.2)

# %%
# !pip install openai
# Out:
# Collecting openai
#   Using cached openai-1.23.2-py3-none-any.whl.metadata (21 kB)
# Collecting anyio<5,>=3.5.0 (from openai)
#   Using cached anyio-4.3.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Downloading pydantic-2.7.1-py3-none-any.whl.metadata (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.3/107.3 kB 3.0 MB/s eta 0:00:00
# Collecting sniffio (from openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>4 in ./.venv/lib/python3.12/site-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in ./.venv/lib/python3.12/site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1.9.0->openai)
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.18.2 (from pydantic<3,>=1.9.0->openai)
#   Downloading pydantic_core-2.18.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.5 kB)
# Using cached openai-1.23.2-py3-none-any.whl (311 kB)
# Using cached anyio-4.3.0-py3-none-any.whl (85 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Downloading pydantic-2.7.1-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.3/409.3 kB 10.3 MB/s eta 0:00:0000:01
# Downloading pydantic_core-2.18.2-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 36.4 MB/s eta 0:00:00a 0:00:01
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: sniffio, pydantic-core, h11, distro, annotated-types, pydantic, httpcore, anyio, httpx, openai
# Successfully installed annotated-types-0.6.0 anyio-4.3.0 distro-1.9.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.23.2 pydantic-2.7.1 pydantic-core-2.18.2 sniffio-1.3.1

# %%
# !pip install span_marker
# Out:
# Collecting span_marker
#   Downloading span_marker-1.5.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: torch in ./.venv/lib/python3.12/site-packages (from span_marker) (2.2.2)
# Collecting accelerate (from span_marker)
#   Downloading accelerate-0.29.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: transformers>=4.19.0 in ./.venv/lib/python3.12/site-packages (from span_marker) (4.40.0)
# Requirement already satisfied: datasets>=2.14.0 in ./.venv/lib/python3.12/site-packages (from span_marker) (2.19.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from span_marker) (24.0)
# Requirement already satisfied: evaluate in ./.venv/lib/python3.12/site-packages (from span_marker) (0.4.1)
# Collecting seqeval (from span_marker)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from span_marker) (3.1.3)
# Requirement already satisfied: huggingface-hub in ./.venv/lib/python3.12/site-packages (from span_marker) (0.22.2)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from datasets>=2.14.0->span_marker) (3.13.4)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.12/site-packages (from datasets>=2.14.0->span_marker) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in ./.venv/lib/python3.12/site-packages (from datasets>=2.14.0->span_marker) (16.0.0)
# Requirement already satisfied: pyarrow-hotfix in ./.venv/lib/python3.12/site-packages (from datasets>=2.14.0->span_marker) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in ./.venv/lib/python3.12/site-packages (from datasets>=2.14.0->span_marker) (0.3.8)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (from datasets>=2.14.0->span_marker) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in ./.venv/lib/python3.12/site-packages (from datasets>=2.14.0->span_marker) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in ./.venv/lib/python3.12/site-packages (from datasets>=2.14.0->span_marker) (4.66.2)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.12/site-packages (from datasets>=2.14.0->span_marker) (3.4.1)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.12/site-packages (from datasets>=2.14.0->span_marker) (0.70.16)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in ./.venv/lib/python3.12/site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets>=2.14.0->span_marker) (2024.3.1)
# Requirement already satisfied: aiohttp in ./.venv/lib/python3.12/site-packages (from datasets>=2.14.0->span_marker) (3.9.5)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.12/site-packages (from datasets>=2.14.0->span_marker) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv/lib/python3.12/site-packages (from huggingface-hub->span_marker) (4.11.0)
# Requirement already satisfied: regex!=2019.12.17 in ./.venv/lib/python3.12/site-packages (from transformers>=4.19.0->span_marker) (2024.4.16)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in ./.venv/lib/python3.12/site-packages (from transformers>=4.19.0->span_marker) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in ./.venv/lib/python3.12/site-packages (from transformers>=4.19.0->span_marker) (0.4.3)
# Requirement already satisfied: psutil in ./.venv/lib/python3.12/site-packages (from accelerate->span_marker) (5.9.8)
# Requirement already satisfied: sympy in ./.venv/lib/python3.12/site-packages (from torch->span_marker) (1.12)
# Requirement already satisfied: networkx in ./.venv/lib/python3.12/site-packages (from torch->span_marker) (3.3)
# Requirement already satisfied: responses<0.19 in ./.venv/lib/python3.12/site-packages (from evaluate->span_marker) (0.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2->span_marker) (2.1.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in ./.venv/lib/python3.12/site-packages (from seqeval->span_marker) (1.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.14.0->span_marker) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.14.0->span_marker) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.14.0->span_marker) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.14.0->span_marker) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.14.0->span_marker) (1.9.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.19.0->datasets>=2.14.0->span_marker) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests>=2.19.0->datasets>=2.14.0->span_marker) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.19.0->datasets>=2.14.0->span_marker) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests>=2.19.0->datasets>=2.14.0->span_marker) (2024.2.2)
# Requirement already satisfied: scipy>=1.6.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn>=0.21.3->seqeval->span_marker) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn>=0.21.3->seqeval->span_marker) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn>=0.21.3->seqeval->span_marker) (3.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas->datasets>=2.14.0->span_marker) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas->datasets>=2.14.0->span_marker) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas->datasets>=2.14.0->span_marker) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.12/site-packages (from sympy->torch->span_marker) (1.3.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.14.0->span_marker) (1.16.0)
# Downloading span_marker-1.5.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.0 MB/s eta 0:00:00
# Downloading accelerate-0.29.3-py3-none-any.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 8.8 MB/s eta 0:00:00
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (pyproject.toml) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16161 sha256=219a0e308610ad670c1bca46ec95379b66dcd6cfaec6dbe26777df2f91b25ed1
#   Stored in directory: /Users/praveenhosdrug/Library/Caches/pip/wheels/5f/b8/73/0b2c1a76b701a677653dd79ece07cfabd7457989dbfbdcd8d7
# Successfully built seqeval
# Installing collected packages: seqeval, accelerate, span_marker
# Successfully installed accelerate-0.29.3 seqeval-1.2.2 span_marker-1.5.0

# %%
# !pip install pipreqs
# Out:
# Collecting pipreqs
#   Downloading pipreqs-0.5.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting docopt==0.6.2 (from pipreqs)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ipython==8.12.3 (from pipreqs)
#   Downloading ipython-8.12.3-py3-none-any.whl.metadata (5.7 kB)
# Collecting nbconvert<8.0.0,>=7.11.0 (from pipreqs)
#   Downloading nbconvert-7.16.3-py3-none-any.whl.metadata (8.2 kB)
# Collecting yarg==0.1.9 (from pipreqs)
#   Downloading yarg-0.1.9-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting backcall (from ipython==8.12.3->pipreqs)
#   Downloading backcall-0.2.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: decorator in ./.venv/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs) (0.19.1)
# Requirement already satisfied: matplotlib-inline in ./.venv/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs) (0.1.7)
# Collecting pickleshare (from ipython==8.12.3->pipreqs)
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in ./.venv/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs) (2.17.2)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs) (0.6.3)
# Requirement already satisfied: traitlets>=5 in ./.venv/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs) (4.9.0)
# Requirement already satisfied: appnope in ./.venv/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs) (0.1.4)
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (from yarg==0.1.9->pipreqs) (2.31.0)
# Collecting beautifulsoup4 (from nbconvert<8.0.0,>=7.11.0->pipreqs)
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from nbconvert<8.0.0,>=7.11.0->pipreqs)
#   Downloading bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert<8.0.0,>=7.11.0->pipreqs)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: jinja2>=3.0 in ./.venv/lib/python3.12/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (3.1.3)
# Requirement already satisfied: jupyter-core>=4.7 in ./.venv/lib/python3.12/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (5.7.2)
# Collecting jupyterlab-pygments (from nbconvert<8.0.0,>=7.11.0->pipreqs)
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: markupsafe>=2.0 in ./.venv/lib/python3.12/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (2.1.5)
# Collecting mistune<4,>=2.0.3 (from nbconvert<8.0.0,>=7.11.0->pipreqs)
#   Downloading mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert<8.0.0,>=7.11.0->pipreqs)
#   Downloading nbclient-0.10.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting nbformat>=5.7 (from nbconvert<8.0.0,>=7.11.0->pipreqs)
#   Downloading nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging in ./.venv/lib/python3.12/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (24.0)
# Collecting pandocfilters>=1.4.1 (from nbconvert<8.0.0,>=7.11.0->pipreqs)
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting tinycss2 (from nbconvert<8.0.0,>=7.11.0->pipreqs)
#   Downloading tinycss2-1.3.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: six>=1.9.0 in ./.venv/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert<8.0.0,>=7.11.0->pipreqs) (1.16.0)
# Collecting webencodings (from bleach!=5.0.0->nbconvert<8.0.0,>=7.11.0->pipreqs)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython==8.12.3->pipreqs) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.12/site-packages (from jupyter-core>=4.7->nbconvert<8.0.0,>=7.11.0->pipreqs) (3.11.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.12/site-packages (from nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs) (8.6.1)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs)
#   Downloading fastjsonschema-2.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting jsonschema>=2.6 (from nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs)
#   Downloading jsonschema-4.21.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython==8.12.3->pipreqs) (0.7.0)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.12/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython==8.12.3->pipreqs) (0.2.13)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert<8.0.0,>=7.11.0->pipreqs)
#   Using cached soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests->yarg==0.1.9->pipreqs) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests->yarg==0.1.9->pipreqs) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests->yarg==0.1.9->pipreqs) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests->yarg==0.1.9->pipreqs) (2024.2.2)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.12/site-packages (from stack-data->ipython==8.12.3->pipreqs) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.12/site-packages (from stack-data->ipython==8.12.3->pipreqs) (2.4.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.12/site-packages (from stack-data->ipython==8.12.3->pipreqs) (0.2.2)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs) (23.2.0)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=2.6->nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs)
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=2.6->nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs)
#   Downloading referencing-0.34.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=2.6->nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs)
#   Downloading rpds_py-0.18.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in ./.venv/lib/python3.12/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs) (26.0.2)
# Requirement already satisfied: tornado>=6.2 in ./.venv/lib/python3.12/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs) (6.4)
# Downloading pipreqs-0.5.0-py3-none-any.whl (33 kB)
# Downloading ipython-8.12.3-py3-none-any.whl (798 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.3/798.3 kB 11.6 MB/s eta 0:00:00 0:00:01
# Downloading yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# Downloading nbconvert-7.16.3-py3-none-any.whl (257 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.4/257.4 kB 33.2 MB/s eta 0:00:00
# Downloading bleach-6.1.0-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.8/162.8 kB 18.9 MB/s eta 0:00:00
# Downloading mistune-3.0.2-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 5.1 MB/s eta 0:00:00
# Downloading nbclient-0.10.0-py3-none-any.whl (25 kB)
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 10.5 MB/s eta 0:00:00
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Downloading tinycss2-1.3.0-py3-none-any.whl (22 kB)
# Downloading fastjsonschema-2.19.1-py3-none-any.whl (23 kB)
# Downloading jsonschema-4.21.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 kB 11.5 MB/s eta 0:00:00
# Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading referencing-0.34.0-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.18.0-cp312-cp312-macosx_11_0_arm64.whl (332 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.0/333.0 kB 33.2 MB/s eta 0:00:00
# Building wheels for collected packages: docopt
#   Building wheel for docopt (pyproject.toml) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=daf4f68c8ffcccd576d523ee41e8db43891dc99f4676499ec6cf3be3006ec5cc
#   Stored in directory: /Users/praveenhosdrug/Library/Caches/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built docopt
# Installing collected packages: webencodings, pickleshare, fastjsonschema, docopt, backcall, tinycss2, soupsieve, rpds-py, pandocfilters, mistune, jupyterlab-pygments, defusedxml, bleach, yarg, referencing, beautifulsoup4, jsonschema-specifications, ipython, jsonschema, nbformat, nbclient, nbconvert, pipreqs
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.23.0
#     Uninstalling ipython-8.23.0:
#       Successfully uninstalled ipython-8.23.0
# Successfully installed backcall-0.2.0 beautifulsoup4-4.12.3 bleach-6.1.0 defusedxml-0.7.1 docopt-0.6.2 fastjsonschema-2.19.1 ipython-8.12.3 jsonschema-4.21.1 jsonschema-specifications-2023.12.1 jupyterlab-pygments-0.3.0 mistune-3.0.2 nbclient-0.10.0 nbconvert-7.16.3 nbformat-5.10.4 pandocfilters-1.5.1 pickleshare-0.7.5 pipreqs-0.5.0 referencing-0.34.0 rpds-py-0.18.0 soupsieve-2.5 tinycss2-1.3.0 webencodings-0.5.1 yarg-0.1.9
